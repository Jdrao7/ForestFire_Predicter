# %% [markdown]
# ## **Feature Engineering**

# %%
import pandas as pd

# %%
df=pd.read_csv("Algerian_forest_fires_dataset_UPDATE.csv",header=1)

# %%
df1=df.iloc[0:121]
df2=df.iloc[125:]

# %%
df2.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        1
# dtype: int64

# %%
df=pd.concat([df1,df2],ignore_index=True)

# %%
df.columns=df.columns.str.strip()

# %%
df['Classes'].value_counts()
# Out:
# Classes
# fire             131
# not fire          99
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
df.drop(['day','year'],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# month          0
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        1
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# month          0
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# dtype: int64

# %%
cols_to_convert = df.columns[:-8]

# convert columns to integer type
df[cols_to_convert] = df[cols_to_convert].apply(pd.to_numeric,errors='coerce').astype(int)

# %%
df.head()
# Out:
#    month  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  \
# 0      6           29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1      6           29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2      6           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3      6           25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4      6           27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#        Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 241 entries, 0 to 241
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   month        241 non-null    int32
#  1   Temperature  241 non-null    int32
#  2   RH           241 non-null    int32
#  3   Ws           241 non-null    int32
#  4   Rain         241 non-null    object
#  5   FFMC         241 non-null    object
#  6   DMC          241 non-null    object
#  7   DC           241 non-null    object
#  8   ISI          241 non-null    object
#  9   BUI          241 non-null    object
#  10  FWI          241 non-null    object
#  11  Classes      241 non-null    object
# dtypes: int32(4), object(8)
# memory usage: 20.7+ KB

# %%
df['Classes'].unique()
# Out:
# array(['not fire   ', 'fire   ', 'fire', 'fire ', 'not fire', 'not fire ',
#        'not fire     ', 'not fire    '], dtype=object)

# %%
df['Classes']=df['Classes'].apply(lambda x:1 if x.strip()=='fire' else 0)

# %%
df['Classes'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 241 entries, 0 to 241
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   month        241 non-null    int32
#  1   Temperature  241 non-null    int32
#  2   RH           241 non-null    int32
#  3   Ws           241 non-null    int32
#  4   Rain         241 non-null    object
#  5   FFMC         241 non-null    object
#  6   DMC          241 non-null    object
#  7   DC           241 non-null    object
#  8   ISI          241 non-null    object
#  9   BUI          241 non-null    object
#  10  FWI          241 non-null    object
#  11  Classes      241 non-null    int64
# dtypes: int32(4), int64(1), object(7)
# memory usage: 20.7+ KB

# %%
columns_to_float=df.columns[-8:-1]

# %%
columns_to_float
# Out:
# Index(['Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI'], dtype='object')

# %%
df[columns_to_float]=df[columns_to_float].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 241 entries, 0 to 241
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   month        241 non-null    int32
#  1   Temperature  241 non-null    int32
#  2   RH           241 non-null    int32
#  3   Ws           241 non-null    int32
#  4   Rain         241 non-null    float64
#  5   FFMC         241 non-null    float64
#  6   DMC          241 non-null    float64
#  7   DC           241 non-null    float64
#  8   ISI          241 non-null    float64
#  9   BUI          241 non-null    float64
#  10  FWI          241 non-null    float64
#  11  Classes      241 non-null    int64
# dtypes: float64(7), int32(4), int64(1)
# memory usage: 20.7 KB

# %% [markdown]
# ## Since the dataset features are highly correlated we are going to drop some highly correlated features as they don't affect the prediction much

# %%
df.corr()
# Out:
#                 month  Temperature        RH        Ws      Rain      FFMC  \
# month        1.000000    -0.046797 -0.044336 -0.044349  0.033137  0.022196
# Temperature -0.046797     1.000000 -0.649781 -0.292591 -0.326611  0.673268
# RH          -0.044336    -0.649781  1.000000  0.251318  0.221763 -0.642875
# Ws          -0.044349    -0.292591  0.251318  1.000000  0.172746 -0.182603
# Rain         0.033137    -0.326611  0.221763  0.172746  1.000000 -0.549635
# FFMC         0.022196     0.673268 -0.642875 -0.182603 -0.549635  1.000000
# DMC          0.069005     0.482988 -0.404414 -0.008159 -0.288820  0.599576
# DC           0.127943     0.373105 -0.222229  0.073218 -0.297980  0.503108
# ISI          0.066934     0.602329 -0.684549  0.000955 -0.347830  0.738252
# BUI          0.086211     0.456928 -0.349416  0.024352 -0.299940  0.587967
# FWI          0.083624     0.565439 -0.578363  0.025737 -0.324535  0.689745
# Classes      0.024299     0.513396 -0.427870 -0.079075 -0.379865  0.767711
#
#                   DMC        DC       ISI       BUI       FWI   Classes
# month        0.069005  0.127943  0.066934  0.086211  0.083624  0.024299
# Temperature  0.482988  0.373105  0.602329  0.456928  0.565439  0.513396
# RH          -0.404414 -0.222229 -0.684549 -0.349416 -0.578363 -0.427870
# Ws          -0.008159  0.073218  0.000955  0.024352  0.025737 -0.079075
# Rain        -0.288820 -0.297980 -0.347830 -0.299940 -0.324535 -0.379865
# FFMC         0.599576  0.503108  0.738252  0.587967  0.689745  0.767711
# DMC          1.000000  0.875078  0.677629  0.982101  0.874918  0.581717
# DC           0.875078  1.000000  0.504947  0.941623  0.737765  0.507206
# ISI          0.677629  0.504947  1.000000  0.641005  0.922331  0.732586
# BUI          0.982101  0.941623  0.641005  1.000000  0.856896  0.582785
# FWI          0.874918  0.737765  0.922331  0.856896  1.000000  0.716871
# Classes      0.581717  0.507206  0.732586  0.582785  0.716871  1.000000

# %%
dropped_features=set()
corr_matrix=df.corr().abs()
threshold=0.85

# %%
for i in range(len(corr_matrix.columns)):
    for j in range(i):
        if corr_matrix.iloc[i,j]>threshold:
            col_j=corr_matrix.columns[j]
            if col_j not in dropped_features:
                dropped_features.add(col_j)

df.drop(columns=dropped_features,inplace=True)

# %%
dropped_features
# Out:
# {'BUI', 'DC', 'DMC', 'ISI'}

# %%
df['Rain'] = df['Rain'].apply(lambda x: 0 if x == 0 else 1)

# %%
df.columns
# Out:
# Index(['month', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC', 'FWI', 'Classes'], dtype='object')

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression(max_iter=10000)

# %%
X=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=45)

# %% [markdown]
# ## StandardScaler improve model accuracy in LogisticRegression otherwise low accuracy was seen

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Convert back to DataFrame with original columns as without it the pred accuracy in numpy array form is coming 55% idk why?
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
X_train_scaled, y_train = smote.fit_resample(X_train_scaled, y_train)

# %%
model.fit(X_train_scaled,y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %%
df.corr()
# Out:
#                 month  Temperature        RH        Ws      Rain      FFMC  \
# month        1.000000    -0.046797 -0.044336 -0.044349 -0.046840  0.022196
# Temperature -0.046797     1.000000 -0.649781 -0.292591 -0.253864  0.673268
# RH          -0.044336    -0.649781  1.000000  0.251318  0.119831 -0.642875
# Ws          -0.044349    -0.292591  0.251318  1.000000  0.033986 -0.182603
# Rain        -0.046840    -0.253864  0.119831  0.033986  1.000000 -0.624676
# FFMC         0.022196     0.673268 -0.642875 -0.182603 -0.624676  1.000000
# FWI          0.083624     0.565439 -0.578363  0.025737 -0.582424  0.689745
# Classes      0.024299     0.513396 -0.427870 -0.079075 -0.646797  0.767711
#
#                   FWI   Classes
# month        0.083624  0.024299
# Temperature  0.565439  0.513396
# RH          -0.578363 -0.427870
# Ws           0.025737 -0.079075
# Rain        -0.582424 -0.646797
# FFMC         0.689745  0.767711
# FWI          1.000000  0.716871
# Classes      0.716871  1.000000

# %%
y_pred=model.predict(X_test_scaled)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.9591836734693877

# %%
confusion_matrix(y_pred,y_test)
# Out:
# array([[21,  1],
#        [ 1, 26]], dtype=int64)

# %%
classification_report(y_pred,y_test)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.95      0.95      0.95        22\n           1       0.96      0.96      0.96        27\n\n    accuracy                           0.96        49\n   macro avg       0.96      0.96      0.96        49\nweighted avg       0.96      0.96      0.96        49\n'

# %% [markdown]
# ## **Hyperparameter tuning using Cross-Validation and GridSearch**

# %%
penalty=['l1','l2']
c_values=[100,10,1.0,0.1,0.01]
solver=['saga']

# %%
params=dict(penalty=penalty,C=c_values,solver=solver) # list inside dict

# %%
from sklearn.model_selection import StratifiedKFold

# %%
cv=StratifiedKFold()

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid=GridSearchCV(estimator=model,param_grid=params,scoring='accuracy',cv=cv,n_jobs=-1)

# %%
grid.fit(X_train_scaled,y_train)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=LogisticRegression(max_iter=10000), n_jobs=-1,
#              param_grid={'C': [100, 10, 1.0, 0.1, 0.01],
#                          'penalty': ['l1', 'l2'], 'solver': ['saga']},
#              scoring='accuracy')

# %%
grid.best_score_
# Out:
# 0.9772727272727273

# %%
model_grid=grid.best_estimator_

# %%
y_pred_grid=model_grid.predict(X_test_scaled)

# %%
accuracy_score(y_pred_grid,y_test)
# Out:
# 0.9795918367346939

# %%
param_grid = [
    {'penalty': ['l1'], 'C': [0.01, 0.1, 1], 'solver': ['saga','liblinear']},
    {'penalty': ['l2'], 'C': [0.01, 0.1, 1], 'solver': ['saga','liblinear','lbfgs','newton-cg','sag']},
    {'penalty': ['elasticnet'], 'C': [0.01, 0.1, 1], 'solver': ['saga'], 'l1_ratio': [0.0, 0.5, 1.0]}
] # dict inside list

# %%
grid2=GridSearchCV(estimator=model,param_grid=param_grid,scoring='accuracy',cv=cv,n_jobs=-1)

# %%
grid2.fit(X_train_scaled,y_train)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=LogisticRegression(max_iter=10000), n_jobs=-1,
#              param_grid=[{'C': [0.01, 0.1, 1], 'penalty': ['l1'],
#                           'solver': ['saga', 'liblinear']},
#                          {'C': [0.01, 0.1, 1], 'penalty': ['l2'],
#                           'solver': ['saga', 'liblinear', 'lbfgs', 'newton-cg',
#                                      'sag']},
#                          {'C': [0.01, 0.1, 1], 'l1_ratio': [0.0, 0.5, 1.0],
#                           'penalty': ['elasticnet'], 'solver': ['saga']}],
#              scoring='accuracy')

# %%
grid2.best_score_
# Out:
# 0.9772727272727273

# %% [markdown]
# ## Since hyperparameter tuning is giving more accuracy therefore we are using logisticReg grid2 best model only as our final model for production

# %%
import pickle

# %%
with open('model.pkl','wb') as f:
    pickle.dump(grid2.best_estimator_,f)

# %% [markdown]
# ## **We can see How much features are correlated with target**

# %%
model.coef_
# Out:
# array([[-0.03848508,  0.18860054, -0.22306535,  0.21172515, -0.57534041,
#          3.14431615,  2.71281702]])

# %%
model.coef_
# Out:
# array([[-0.03848508,  0.18860054, -0.22306535,  0.21172515, -0.57534041,
#          3.14431615,  2.71281702]])

# %%
df.columns
# Out:
# Index(['month', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC', 'FWI', 'Classes'], dtype='object')

# %%
feature_names = X.columns
coefficients = model.coef_[0]  

for feat, coef in zip(feature_names, coefficients):
    if feat == 'Rain':
        print(f"Rain coefficient: {coef}")
# Out:
# Rain coefficient: -0.575340409939505

# %%
print(df['Rain'].value_counts()) # As you can see the rain is positively related with fires which is absurd need to drop Rain but its also an important feature for now just covertinf it into binary classsification
# Out:
# Rain
# 0    133
# 1    108
# Name: count, dtype: int64

# %%
import seaborn as sns
sns.countplot(x='Rain', hue='Classes', data=df)
# Out:
# <Axes: xlabel='Rain', ylabel='count'>
